# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Xyber/ML/blob/main/LAB4/LAB4_DataqualityAsssesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4: Data Quality Assessment & Preprocessing

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
#Load Dataset
pd.set_option("display.max_columns", None)

df = pd.read_csv("train.csv")
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
#Check Data Types
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# Convert Incorrect Data types to Correct
df['MSSubClass'] = df['MSSubClass'].astype('category')
df['MoSold'] = df['MoSold'].astype('category')
df['YrSold'] = df['YrSold'].astype('category')
df['Id'] = df['Id'].astype('str')


# Check results
df.dtypes
# Out:
# Id                       object
# MSSubClass             category
# MSZoning                 object
# LotFrontage             float64
# LotArea                   int64
#                       ...
# MoSold                 category
# YrSold                 category
# SaleType         string[python]
# SaleCondition            object
# SalePrice                 int64
# Length: 81, dtype: object

# %%
#Detect Missing Values
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df_missing = df.copy()
df_missing.loc[0:5, 'MSSubClass'] = np.nan
df_missing.isna().sum()
# Out:
# Id                 0
# MSSubClass         6
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
print("Original shape: ", df.shape)
print("After removing some values: ", df_missing.shape)
# Out:
# Original shape:  (1460, 81)
# After removing some values:  (1460, 81)

# %%
df_missing.head(10)
# Out:
#    Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1        NaN       RL         65.0     8450   Pave   NaN      Reg
# 1   2        NaN       RL         80.0     9600   Pave   NaN      Reg
# 2   3        NaN       RL         68.0    11250   Pave   NaN      IR1
# 3   4        NaN       RL         60.0     9550   Pave   NaN      IR1
# 4   5        NaN       RL         84.0    14260   Pave   NaN      IR1
# 5   6        NaN       RL         85.0    14115   Pave   NaN      IR1
# 6   7         20       RL         75.0    10084   Pave   NaN      Reg
# 7   8         60       RL          NaN    10382   Pave   NaN      IR1
# 8   9         50       RM         51.0     6120   Pave   NaN      Reg
# 9  10        190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
#Strategy 1 Remove Records
df_removed = df_missing.dropna()
df_removed.shape
# Out:
# (0, 81)

# %%
df_removed.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
#Strategy 2 Mean Manipulation
df_missing.head(10)
# Out:
#    Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1        NaN       RL         65.0     8450   Pave   NaN      Reg
# 1   2        NaN       RL         80.0     9600   Pave   NaN      Reg
# 2   3        NaN       RL         68.0    11250   Pave   NaN      IR1
# 3   4        NaN       RL         60.0     9550   Pave   NaN      IR1
# 4   5        NaN       RL         84.0    14260   Pave   NaN      IR1
# 5   6        NaN       RL         85.0    14115   Pave   NaN      IR1
# 6   7         20       RL         75.0    10084   Pave   NaN      Reg
# 7   8         60       RL          NaN    10382   Pave   NaN      IR1
# 8   9         50       RM         51.0     6120   Pave   NaN      Reg
# 9  10        190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
df_imputed_mode = df_missing.copy()

df_imputed_mode['MSSubClass'] = df_imputed_mode['MSSubClass'].fillna(
    df_imputed_mode['MSSubClass'].mode()[0]
)

df_imputed_mode.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          6
# Length: 81, dtype: int64

# %%
df_imputed_mean.head(10)
# Out:
#    Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1        NaN       RL         65.0     8450   Pave   NaN      Reg
# 1   2        NaN       RL         80.0     9600   Pave   NaN      Reg
# 2   3        NaN       RL         68.0    11250   Pave   NaN      IR1
# 3   4        NaN       RL         60.0     9550   Pave   NaN      IR1
# 4   5        NaN       RL         84.0    14260   Pave   NaN      IR1
# 5   6        NaN       RL         85.0    14115   Pave   NaN      IR1
# 6   7         20       RL         75.0    10084   Pave   NaN      Reg
# 7   8         60       RL          NaN    10382   Pave   NaN      IR1
# 8   9         50       RM         51.0     6120   Pave   NaN      Reg
# 9  10        190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
#Strategy 3 Median Imputation
df_missing = df.copy()
df_missing.loc[0:5, 'SalePrice'] = np.nan
df_imputed_median = df_missing.copy()

df_imputed_median['SalePrice'].fillna(
    df_imputed_median['SalePrice'].median(),
    inplace=True
)

df_imputed_median.isna().sum()
# Out:
# /tmp/ipython-input-416/1085202.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed_median['SalePrice'].fillna(
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df_imputed_median.head(10)
# Out:
#    Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1         60       RL         65.0     8450   Pave   NaN      Reg
# 1   2         20       RL         80.0     9600   Pave   NaN      Reg
# 2   3         60       RL         68.0    11250   Pave   NaN      IR1
# 3   4         70       RL         60.0     9550   Pave   NaN      IR1
# 4   5         60       RL         84.0    14260   Pave   NaN      IR1
# 5   6         50       RL         85.0    14115   Pave   NaN      IR1
# 6   7         20       RL         75.0    10084   Pave   NaN      Reg
# 7   8         60       RL          NaN    10382   Pave   NaN      IR1
# 8   9         50       RM         51.0     6120   Pave   NaN      Reg
# 9  10        190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
#Handling Outliers
plt.figure(figsize=(6,4))
sns.boxplot(x=df['SalePrice'])
plt.title("Boxplot of SalePrice")
plt.show()

# %%
#Detect Outliers using IQR Method

Q1 = df['SalePrice'].quantile(0.25)
Q3 = df['SalePrice'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['SalePrice'] < lower) | (df['SalePrice'] > upper)]

print("Lower Bound:", lower)
print("Upper Bound:", upper)
print("Number of Outliers:", outliers.shape[0])

outliers.head(15)
# Out:
# Lower Bound: 3937.5
# Upper Bound: 340037.5
# Number of Outliers: 61
#       Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 11    12         60       RL         85.0    11924   Pave   NaN      IR1
# 53    54         20       RL         68.0    50271   Pave   NaN      IR1
# 58    59         60       RL         66.0    13682   Pave   NaN      IR2
# 112  113         60       RL         77.0     9965   Pave   NaN      Reg
# 151  152         20       RL        107.0    13891   Pave   NaN      Reg
# 161  162         60       RL        110.0    13688   Pave   NaN      IR1
# 178  179         20       RL         63.0    17423   Pave   NaN      IR1
# 185  186         75       RM         90.0    22950   Pave   NaN      IR2
# 224  225         20       RL        103.0    13472   Pave   NaN      Reg
# 231  232         60       RL        174.0    15138   Pave   NaN      IR1
# 278  279         20       RL        107.0    14450   Pave   NaN      Reg
# ...

# %%
#Removing Outliers
df_no_outliers = df[(df['SalePrice'] >= lower) & (df['SalePrice'] <= upper)]

print("Original shape:", df.shape)
print("After removing outliers:", df_no_outliers.shape)
# Out:
# Original shape: (1460, 81)
# After removing outliers: (1399, 81)

# %%
#Capping Outliers

lower_cap = df['SalePrice'].quantile(0.05)
upper_cap = df['SalePrice'].quantile(0.95)

df_capped = df.copy()
df_capped['SalePrice'] = df_capped['SalePrice'].clip(lower_cap, upper_cap)

print("Lower Cap:", lower_cap)
print("Upper Cap:", upper_cap)
df_capped.head()
# Out:
# Lower Cap: 88000.0
# Upper Cap: 326099.9999999999
# /tmp/ipython-input-416/1549762786.py:7: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_capped['SalePrice'] = df_capped['SalePrice'].clip(lower_cap, upper_cap)
#   Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1         60       RL         65.0     8450   Pave   NaN      Reg
# 1  2         20       RL         80.0     9600   Pave   NaN      Reg
# 2  3         60       RL         68.0    11250   Pave   NaN      IR1
# 3  4         70       RL         60.0     9550   Pave   NaN      IR1
# 4  5         60       RL         84.0    14260   Pave   NaN      IR1
#
# ...

# %%
#Data Transformation
df[['SalePrice', 'GrLivArea']].head()
# Out:
#    SalePrice  GrLivArea
# 0     208500       1710
# 1     181500       1262
# 2     223500       1786
# 3     140000       1717
# 4     250000       2198

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_scaled = df[['SalePrice', 'GrLivArea']].copy()
df_scaled[['SalePrice', 'GrLivArea']] = scaler.fit_transform(df_scaled)
df_scaled.head()
# Out:
#    SalePrice  GrLivArea
# 0   0.241078   0.259231
# 1   0.203583   0.174830
# 2   0.261908   0.273549
# 3   0.145952   0.260550
# 4   0.298709   0.351168

# %%
#Z-Score Normalization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_standardized = df[['SalePrice', 'GrLivArea']].copy()
df_standardized[['SalePrice', 'GrLivArea']] = scaler.fit_transform(df_standardized)
df_standardized.head()
# Out:
#    SalePrice  GrLivArea
# 0   0.347273   0.370333
# 1   0.007288  -0.482512
# 2   0.536154   0.515013
# 3  -0.515281   0.383659
# 4   0.869843   1.299326

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df_standardized[['SalePrice','GrLivArea']].corr(),
            annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap (Before PCA)")
plt.show()

# %%
#Data Reduction PCA
from sklearn.decomposition import PCA

X = df_standardized[['SalePrice', 'GrLivArea']]

pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)

print("Explained Variance Ratio:", pca.explained_variance_ratio_)
print("Total Explained Variance:", pca.explained_variance_ratio_.sum())
# Out:
# Explained Variance Ratio: [0.85431224 0.14568776]
# Total Explained Variance: 1.0

# %%
plt.figure(figsize=(6,4))
plt.scatter(principal_components[:,0], principal_components[:,1])
plt.title("PCA Projection")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()
